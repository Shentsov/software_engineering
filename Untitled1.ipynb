# %%
# !pip install transformers

# %%
from transformers import pipeline

classifier = pipeline("sentiment-analysis", "blanchefort/rubert-base-cased-sentiment") # базовый

classifier("Я обожаю инжинерию машинного обучения!")
# Out:
# ...
# [{'label': 'POSITIVE', 'score': 0.9795372486114502}]

# %%
classifier = pipeline("sentiment-analysis", "blanchefort/rubert-base-cased-sentiment-med") #для анализа настроений медицинских обзоров

# %%
classifier("Ваши анализы в норме!")
# Out:
# [{'label': 'NEGATIVE', 'score': 0.44044139981269836}]

# %%
classifier = pipeline("sentiment-analysis", "blanchefort/rubert-base-cased-sentiment-rusentiment") #RuSentiment

# %%
classifier("Сегодня прекрасная погода!")
# Out:
# [{'label': 'POSITIVE', 'score': 0.9963107705116272}]

# %%
classifier("Мне нравится этот чёртов день!")
# Out:
# [{'label': 'POSITIVE', 'score': 0.9966968297958374}]

# %%
classifier = pipeline("sentiment-analysis", "blanchefort/rubert-base-cased-sentiment-rurewiews") #RuRewiews

# %%
classifier("Этот предмет позволит нам выбраться в люди!")
# Out:
# [{'label': 'NEUTRAL', 'score': 0.5408925414085388}]

# %%
classifier("Этот никому не нужен и толку от него нет!")
# Out:
# [{'label': 'NEGATIVE', 'score': 0.8612391352653503}]

# %%
classifier = pipeline("sentiment-analysis", "blanchefort/rubert-base-cased-sentiment-mokoron") #RuTweetCorp

# %%
#LABEL_0 - Позитивное сообщение
#LABEL_1 - Негативное сообщение
classifier("Ты ничего не добьешься, если будешь сидеть на месте")
# Out:
# [{'label': 'LABEL_1', 'score': 0.5357173085212708}]

# %%
classifier("Твоя шарлотка чертовски хороша!")
# Out:
# [{'label': 'LABEL_0', 'score': 0.5904105305671692}]
